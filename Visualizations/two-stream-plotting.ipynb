# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import bokeh
import matplotlib as mpl
from matplotlib import rcParams, rc
import matplotlib.colors as mcolors
from matplotlib.ticker import MaxNLocator

plt.style.use('/home/imalsky/isaac-style.txt')

# %%
x= [50.0, 256.25, 462.5, 668.75, 875.0, 1081.25, 1287.5, 1493.75, 1700.0, 1906.25, 2112.5, 2318.75, 2525.0, 2731.25, 2937.5, 3143.75, 3350.0, 3556.25, 3762.5, 3968.75, 4175.0, 4381.25, 4587.5, 4793.75, 5000.0]
vals1= [1.0264743959454106e-10, 1.181252525395664e-10, 1.199569364731104e-10, 1.2066783670064478e-10, 1.210467696932483e-10, 1.2128039474985016e-10, 1.2143958302341999e-10, 1.2155495810632442e-10, 1.2164281274314633e-10, 1.2171134927247211e-10, 1.217665471041306e-10, 1.2181195113064463e-10, 1.2185013038389156e-10, 1.2188239212697893e-10, 1.219101323911813e-10, 1.219342446431535e-10, 1.2195549081392484e-10, 1.2197418101339875e-10, 1.219908272320133e-10, 1.220057477380381e-10, 1.2201925817551235e-10, 1.2203143747169632e-10, 1.220425252726459e-10, 1.2205266002533723e-10, 1.2206200418285508e-10]
vals2= [1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10, 1.2227857880720465e-10]

plt.plot(x, vals1, linewidth=3.5, linestyle='solid', label='Old Version')
plt.plot(x, vals2, linewidth=3.5, linestyle='solid', label='Two Stream')

plt.legend()
plt.xscale('log')
plt.xlabel('Number of Layers')
plt.ylabel(r"Flux ($\mathbf{10^{-6} \ erg/s/cm^2/Hz}$)", fontsize=20, weight='bold')
plt.savefig('/home/imalsky/Desktop/isothermal.pdf')

# %%
x= [50.0, 256.25, 462.5, 668.75, 875.0, 1081.25, 1287.5, 1493.75, 1700.0, 1906.25, 2112.5, 2318.75, 2525.0, 2731.25, 2937.5, 3143.75, 3350.0, 3556.25, 3762.5, 3968.75, 4175.0, 4381.25, 4587.5, 4793.75, 5000.0]
vals1= [1.6766351630434692e-10, 1.9869981822893302e-10, 2.024780746879882e-10, 2.0395351807745192e-10, 2.047421652288023e-10, 2.0522703436740124e-10, 2.05558589792978e-10, 2.057985495319049e-10, 2.059809497229254e-10, 2.0612355565247285e-10, 2.0623861621922887e-10, 2.0633294370221353e-10, 2.064123548342024e-10, 2.0647964649299482e-10, 2.0653741726578271e-10, 2.0658755604053014e-10, 2.0663191787745776e-10, 2.0667078792077767e-10, 2.0670547582531383e-10, 2.0673649057671542e-10, 2.0676458694303332e-10, 2.0678992075175347e-10, 2.068131046084909e-10, 2.0683417321565022e-10, 2.0685368903060942e-10]
vals2= [1.9964852425235086e-10, 2.057081136441223e-10, 2.0640617933546146e-10, 2.0668159127480912e-10, 2.0682972950350997e-10, 2.069193481474986e-10, 2.069813747608285e-10, 2.0702591811689113e-10, 2.0705945585719823e-10, 2.070859081074911e-10, 2.0710740487501918e-10, 2.07124753632503e-10, 2.0713942560438868e-10, 2.0715200584014594e-10, 2.0716273030851037e-10, 2.0717196876939503e-10, 2.071802921454534e-10, 2.0718745585234494e-10, 2.0719390387301913e-10, 2.0719960359235154e-10, 2.0720477748011287e-10, 2.0720944623449904e-10, 2.0721381620744398e-10, 2.072176871400957e-10, 2.0722134663123646e-10]

from matplotlib.pyplot import figure

figure(figsize=(12, 6), dpi=80)

#plt.plot(x, 1 - np.asarray(vals1) / vals1[-1], linewidth=3.5, linestyle='dotted',color='black', label='Riemann Sum Radiative Transfer')
plt.plot(x, 1 - np.asarray(vals2) / vals2[-1], linewidth=3.5, linestyle='solid',color='black')

plt.xscale('log')
plt.yscale('log')
plt.ylim(1e-4, 1e-1)
plt.xlim(50, 5000)
plt.legend()
plt.xlabel('Number of Layers', fontsize=20, weight='bold')
plt.ylabel(r"Fractional Error", fontsize=20, weight='bold')
plt.savefig('/home/imalsky/Desktop/layer-test.pdf')
# Out:
# No handles with labels found to put in legend.
